# %%
pip install psycopg2
# Out:
# ...
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [23 lines of output]
#       running egg_info
#       creating /private/var/folders/qp/65q347gs0g1bnwxt8wqj3xsw0000gn/T/pip-pip-egg-info-0jvymwbi/psycopg2.egg-info
#       writing /private/var/folders/qp/65q347gs0g1bnwxt8wqj3xsw0000gn/T/pip-pip-egg-info-0jvymwbi/psycopg2.egg-info/PKG-INFO
#       writing dependency_links to /private/var/folders/qp/65q347gs0g1bnwxt8wqj3xsw0000gn/T/pip-pip-egg-info-0jvymwbi/psycopg2.egg-info/dependency_links.txt
#       writing top-level names to /private/var/folders/qp/65q347gs0g1bnwxt8wqj3xsw0000gn/T/pip-pip-egg-info-0jvymwbi/psycopg2.egg-info/top_level.txt
#       writing manifest file '/private/var/folders/qp/65q347gs0g1bnwxt8wqj3xsw0000gn/T/pip-pip-egg-info-0jvymwbi/psycopg2.egg-info/SOURCES.txt'
#
#       Error: pg_config executable not found.
#
# ...
